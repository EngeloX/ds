# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('data/nanprocessingdata.csv')
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#    ID  Площадь (кв. м)  Число комнат  Возраст дома (лет)  Цена (млн руб.) Тип недвижимости Район
# 0   1             80.0           3.0                20.0              8.0         квартира     А
# 1   2            100.0           NaN               150.0             10.0              дом     Б
# 2   3           2000.0           2.0                 NaN             50.0         квартира     А
# 3   4              NaN           4.0                30.0              6.0      апартаменты     В
# 4   5            150.0           3.0                 5.0              NaN              дом     Б
# 5   6            500.0           5.0               300.0             70.0         квартира     А
# 6   7            120.0           3.0                25.0             14.0              дом     Б
# 7   8             80.0           3.0                -5.0              8.0      апартаменты     В
# 8   9           -150.0           3.0                15.0             12.0              дом     Б
# ...

# %%
df.drop
